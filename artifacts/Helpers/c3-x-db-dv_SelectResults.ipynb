# %%
df = spark.sql("""
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_creditcard`' as table_name
    , count(*) as row_count
    , null as max_bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_creditcard`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_customer`' as table_name
    , count(*) as row_count
    , null as max_bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_customer`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_order`' as table_name
    , count(*) as row_count
    , null as max_bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_order`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_orderdetail`' as table_name
    , count(*) as row_count
    , null as max_bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_current_orderdetail`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_creditcard_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_creditcard_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_customer_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_customer_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_order_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_order_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_orderdetail_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_hub_orderdetail_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_customer_order_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_customer_order_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_order_creditcard_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_order_creditcard_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_order_orderdetail_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_lnk_order_orderdetail_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_creditcard_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_creditcard_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_customer_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_customer_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_order_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_order_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_orderdetail_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_pit_orderdetail_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_rc_rvc1_salesorderheader_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_rc_rvc1_salesorderheader_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_referencetable_currency_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_referencetable_currency_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_creditcard_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_creditcard_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_customer_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_customer_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_customercrm_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_customercrm_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_order_currency_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_order_currency_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_order_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_order_result`
    union
    select '`{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_orderdetail_result`' as table_name
    , count(*) as row_count
    , max(bg_loadtimestamp) as bg_loadtimestamp
    from `{c3-x-db-dv#rawvault#database_name}`.`{c3-x-db-dv#rawvault#schema_name}`.`rdv_sat_orderdetail_result`
""")
df.show(n=1000, truncate=False)
